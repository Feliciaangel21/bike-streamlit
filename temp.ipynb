# %%
import streamlit as st
import pandas as pd
import urllib
import json
from helper import *
# Out:
# 2025-07-11 19:00:02.933 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager

# %%
station_url = 'https://tor.publicbikesystem.net/ube/gbfs/v1/en/station_status.json'  
latlon_url = "https://tor.publicbikesystem.net/ube/gbfs/v1/en/station_information"

# %%
df1 = query_station_status(station_url)

# %%
df2 = get_station_latlon(latlon_url)

# %%
join_latlon(df1,df2)
# Out:
#     station_id  num_bikes_available       num_bikes_available_types  \
# 0         7000                   31  {'mechanical': 29, 'ebike': 2}
# 1         7001                   10  {'mechanical': 0, 'ebike': 10}
# 2         7002                   10   {'mechanical': 8, 'ebike': 2}
# 3         7003                    2   {'mechanical': 0, 'ebike': 2}
# 4         7006                    2   {'mechanical': 1, 'ebike': 1}
# ..         ...                  ...                             ...
# 920       8080                    0   {'mechanical': 0, 'ebike': 0}
# 921       8081                    2   {'mechanical': 2, 'ebike': 0}
# 922       8082                    0   {'mechanical': 0, 'ebike': 0}
# 923       8083                    0   {'mechanical': 0, 'ebike': 0}
# 924       7117                    2   {'mechanical': 2, 'ebike': 0}
#
#      num_bikes_disabled  num_docks_available  num_docks_disabled  \
# 0                     0                   15                   1
# 1                     4                    8                   1
# 2                     0                    8                   1
# 3                     1                   10                   1
# 4                     3                   26                   0
# ..                  ...                  ...                 ...
# 920                   0                   14                   0
# 921                   0                    9                   0
# 922                   0                   15                   0
# 923                   0                   11                   0
# 924                   0                   15                   2
#
#           last_reported  is_charging_station      status  is_installed  \
# 0   2025-07-11 12:06:58                False  IN_SERVICE             1
# 1   2025-07-11 12:08:18                 True  IN_SERVICE             1
# 2   2025-07-11 12:08:56                False  IN_SERVICE             1
# 3   2025-07-11 12:07:41                False  IN_SERVICE             1
# 4   2025-07-11 12:07:13                False  IN_SERVICE             1
# ..                  ...                  ...         ...           ...
# 920 2025-07-11 12:08:20                False  IN_SERVICE             1
# 921 2025-07-11 12:09:08                False  IN_SERVICE             1
# 922 2025-07-11 12:06:22                False  IN_SERVICE             1
# 923 2025-07-11 12:09:08                False  IN_SERVICE             1
# 924 2025-07-11 12:07:25                False  IN_SERVICE             1
#
#      is_renting  is_returning traffic  mechanical  ebike        lat        lon
# 0             1             1    None          29      2  43.639832 -79.395954
# 1             1             1    None           0     10  43.664964 -79.383550
# 2             1             1    None           8      2  43.667131 -79.399555
# 3             1             1    None           0      2  43.667018 -79.402796
# 4             1             1    None           1      1  43.660439 -79.385525
# ..          ...           ...     ...         ...    ...        ...        ...
# 920           1             1    None           0      0  43.783430 -79.299559
# 921           1             1    None           2      0  43.783271 -79.317328
# 922           1             1    None           0      0  43.778263 -79.281750
# 923           1             1    None           0      0  43.759071 -79.189453
# 924           1             1    None           2      0  43.674180 -79.367958
#
# [925 rows x 17 columns]
